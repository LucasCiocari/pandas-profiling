# %% [markdown]
# ## pandas-profiling Meteorites example
# Source of data: https://data.nasa.gov/Space-Science/Meteorite-Landings/gh4g-9sfh

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import pandas_profiling
import numpy as np

# %%
# %%javascript
# require.config({
# paths: {
# d3: "https://d3js.org/d3.v5.min",
# mathjs: "https://unpkg.com/mathjs@6.2.3/dist/math.min"
# }
# });
#
# require(["d3", "math"], function(d3, mathjs) {
# window.d3 = d3;
# window.mathjs = mathjs;
# });

# %% [markdown]
# ### Load and prepare example dataset
# We add some fake variables for illustrating pandas-profiling capabilities

# %%
# df=pd.read_csv(r"C:\Users\Lucas\Documents\GitHub\TCC-LucasCiocari-2019\pandas-profiling\examples\Meteorite_Landings.csv", parse_dates=['year'], encoding='UTF-8')

# # Note: Pandas does not support dates before 1880, so we ignore these for this analysis
# df['year'] = pd.to_datetime(df['year'], errors='coerce')

# # Example: Constant variable
# df['source'] = "NASA"

# # Example: Boolean variable
# df['boolean'] = np.random.choice([True, False], df.shape[0])

# # Example: Mixed with base types
# df['mixed'] = np.random.choice([1, "A"], df.shape[0])

# # Example: Highly correlated variables
# df['reclat_city'] = df['reclat'] + np.random.normal(scale=5,size=(len(df)))

# # Example: Duplicate observations
# duplicates_to_add = pd.DataFrame(df.iloc[0:10])
# duplicates_to_add[u'name'] = duplicates_to_add[u'name'] + " copy"

# df = df.append(duplicates_to_add, ignore_index=True)

# columns = ["symboling","normalized-losses","make","fuel-type","aspiration","num-of-doors","body-style","drive-wheels","engine-location","wheel-base","length","width","height","curb-weight","engine-type","num-of-cylinders","engine-size","fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm","city-mpg","highway-mpg","price"]
# df = pd.read_csv('imports-85.data', names=columns)

df = pd.DataFrame({'porta': ['duas', 'quatro', 'duas', 'quatro', 'quatro', 'duas', 'duas'],
                    'combustivel': ['gas', 'diesel', 'gas', 'gas', 'diesel', 'diesel', 'gas'],
                   'body-style': ['sedan', 'hatch', 'hatch', 'sedan', 'sedan', 'hatch', 'hatch']
                    })

# %% [markdown]
# ### Inline report without saving object

# %%
pandas_profiling.ProfileReport(df)
# Out:
# C:\Users\Lucas\AppData\Roaming\Python\Python37\site-packages\pandas_profiling-1.4.1-py3.7.egg\pandas_profiling\describe.py:420: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
# <meta charset="UTF-8">
#
# <style>
#     @import url('https://fonts.googleapis.com/css?family=Roboto&display=swap');
#
#     .variablerow {
#         border: 1px solid #e1e1e8;
#         border-top: hidden;
#         padding-top: 1em;
#         padding-bottom: 1em;
#         padding-left: 1em;
#         padding-right: 1em;
#     }
#
#     .headerrow {
#         border: 1px solid #e1e1e8;
#         background-color: #f5f5f5;
#         padding: 2em;
#     }
#
#     .namecol {
#         margin-top: -1em;
#         overflow-x: auto;
#     }
#
#     .dl-horizontal dt {
#         text-align: left;
#         padding-right: 1em;
#         white-space: normal;
#     }
#
#     .dl-horizontal dd {
#         margin-left: 0;
#     }
#
#     .ignore {
#         opacity: 0.4;
#     }
#
#     .container.pandas-profiling {
#         max-width: 975px;
#     }
#
#     .col-md-12 {
#         padding-left: 2em;
#     }
#
#     .indent {
#         margin-left: 1em;
#     }
#
#     .center-img {
#         margin-left: auto !important;
#         margin-right: auto !important;
#         display: block;
#     }
#
#     /* Table example_values */
#     table.example_values {
#         border: 0;
#     }
#
#     .example_values th {
#         border: 0;
#         padding: 0;
#         color: #555;
#         font-weight: 600;
#     }
#
#     .example_values tr,
#     .example_values td {
#         border: 0;
#         padding: 0;
#         color: #555;
#     }
#
#     /* STATS */
#     table.stats {
#         border: 0;
#     }
#
#     .stats th {
#         border: 0;
#         padding: 0 1em 0 0;
#         color: #555;
#         font-weight: 600;
#     }
#
#     .stats tr {
#         border: 0;
#     }
#
#     .stats td {
#         color: #555;
#         padding: 1px;
#         border: 0;
#     }
#
#
#     /* Sample table */
#     table.sample {
#         border: 0;
#         margin-bottom: 2em;
#         margin-left: 1em;
#     }
#
#     .sample tr {
#         border: 0;
#     }
#
#     .sample td,
#     .sample th {
#         padding: 0.5em;
#         white-space: nowrap;
#         border: none;
#
#     }
#
#     .sample thead {
#         border-top: 0;
#         border-bottom: 2px solid #ddd;
#     }
#
#
#     /* There is no good solution available to make the divs equal height and then center ... */
#     .histogram {
#         margin-top: 3em;
#     }
#
#     /* Freq table */
#
#     table.freq {
#         margin-bottom: 2em;
#         border: 0;
#     }
#
#     table.freq th,
#     table.freq tr,
#     table.freq td {
#         border: 0;
#         padding: 0;
#     }
#
#     .freq thead {
#         font-weight: 600;
#         white-space: nowrap;
#         overflow: hidden;
#         text-overflow: ellipsis;
#
#     }
#
#     td.fillremaining {
#         width: auto;
#         max-width: none;
#     }
#
#     td.number,
#     th.number {
#         text-align: right;
#     }
#
#     /* Freq mini */
#     .freq.mini td {
#         width: 50%;
#         padding: 1px;
#         font-size: 12px;
#
#     }
#
#     table.freq.mini {
#         width: 100%;
#     }
#
#     .freq.mini th {
#         overflow: hidden;
#         text-overflow: ellipsis;
#         white-space: nowrap;
#         max-width: 5em;
#         font-weight: 400;
#         text-align: right;
#         padding-right: 0.5em;
#     }
#
#     .missing {
#         color: rgb(209, 60, 75);
#     }
#
#     .alert,
#     .alert>th,
#     .alert>td {
#         color: rgb(209, 60, 75);
#     }
#
#
#     /* Bars in tables */
#     .freq .bar {
#         float: left;
#         width: 0;
#         height: 100%;
#         line-height: 20px;
#         color: #fff;
#         text-align: center;
#         background-color: rgb(66, 136, 181);
#         border-radius: 3px;
#         margin-right: 4px;
#     }
#
#     .other .bar {
#         background-color: #999;
#     }
#
#     .missing .bar {
#         background-color: rgb(209, 60, 75);
#     }
#
#     .tooltip-inner {
#         width: 100%;
#         white-space: nowrap;
#         text-align: left;
#     }
#
#     .extrapadding {
#         padding: 2em;
#     }
#
#     .pp-anchor {}
#
#     /*Warnings and Suggestions collapses*/
#     .panel-heading .collapseButton:after {
#         font-family: 'FontAwesome';
#         content: "\f106";
#         font-size: 14px;
#         font-weight: bold;
#     }
#
#     .panel-heading .collapseButton.collapsed:after {
#         -webkit-transform: rotate(180deg);
#         -moz-transform: rotate(180deg);
#         transform: rotate(180deg);
#         display: inline-block;
#     }
#
#     .btn-hover-dark {
#         background-color: #eeeeee;
#     }
#
#     .btn-hover-dark:hover {
#         background-color: #dddddd;
#     }
#
#     .btn:focus {
#         outline: none;
#     }
#
#     /*Help*/
#     .help-button:after {
#         font-family: 'FontAwesome';
#         content: "\f29c";
#         font-size: 14px;
#         font-weight: normal;
#         margin-left: 5px;
#         font-size: 17px;
#         color: #000000;
#         cursor: pointer;
#     }
#
#     .help-button:hover {
#         text-decoration: none;
#     }
#
#     .inline-block {
#         display: inline-block;
#     }
#
#     .help {
#         padding-left: 1em;
#         padding-right: 1em;
#         width: 350px;
#     }
#
#     .highlight {
#         fill-opacity: 1;
#         stroke-opacity: 1;
#     }
#
#     .fade {
#         fill-opacity: 0.06;
#         stroke-opacity: 0;
#     }
#
#     .select_item {
#         width: 300px;
#         height: 46px;
#         border-radius: 2%;
#         border: 1px black solid;
#         text-align: center;
#         font-family: 'Roboto', sans-serif;
#         font-size: 16px;
#     }
#
#     svg {
#         background-color: rgb(222, 222, 222);
#     }
#
#     .data-text {
#         fill: rgb(228, 231, 241);
#         font-size: 20px;
#         text-align: center;
#         background-color: black;
#         font-family: 'Roboto', sans-serif;
#     }
# </style>
#
# <div class="container pandas-profiling">
#     <script>
#         if (typeof id !== 'undefined') {
#             id++;
#         } else {
#             var id = 0;
#         }
#     </script>
# <script>
#
# 	function plotBidGraph(data, full_matrix) {
#
# 		var dimensions = Object.keys(data)
# 		var labels = [];
# 		var matrix = [];
#
# 		const r_dim_color = "#f9d5bb"
# 		const l_dim_colors = ["#f66767", "#315b96", "#3c3d47", "#42b883"];
# 		const width = 600
# 		const height = 600
#
# 		const innerRadius = 200
# 		const outerRadius = 215
#
# 		const entity_padding = 0.05
# 		var select_a = document.getElementById('select-a'+id);
# 		var select_b = document.getElementById('select-b'+id);
#
#
#
# 		/*
# 		*Funções
# 		*/
# 		node_mouseover = (d) => {
# 			d3.selectAll("bid_viz"+id).selectAll('.nodes').classed('fade', true)
# 			d3.selectAll("bid_viz"+id).selectAll(`.node-${d.index}`).classed('highlight', true)
# 			d3.selectAll("bid_viz"+id).selectAll('.ribbons').classed('fade', true)
#
#
# 			for (var i = 0; i < matrix.length; i++) {
# 				d3.selectAll("bid_viz"+id).selectAll(`.ribbon-${d.index}-${i}`).classed('highlight', true).moveToFront()
# 				d3.selectAll("bid_viz"+id).selectAll(`.ribbon-${i}-${d.index}`).classed('highlight', true).moveToFront()
# 			}
#
#
# 			var numbers = new Set();
# 			//TODO:  query selector para filter
# 			var x = document.querySelectorAll(`[class^="ribbon-"]`)
# 			for (var i = 0; i < x.length; i++) {
# 				if (x[i].className.baseVal.indexOf(d.index.toString()) != -1) {
# 					numbers.add(x[i].className.baseVal.split(" ")[0].split("-")[1])
# 					numbers.add(x[i].className.baseVal.split(" ")[0].split("-")[2])
# 				}
# 			}
#
# 			for (let item of numbers) d3.selectAll(`.node-${item}`).classed('highlight', true)
# 		}
# 		node_mouseout = (d) => {
# 			d3.selectAll("bid_viz"+id).selectAll('.nodes').classed('fade', false)
# 			d3.selectAll("bid_viz"+id).selectAll(`.node-${d.index}`).classed('highlight', false)
# 			d3.selectAll("bid_viz"+id).selectAll('.ribbons').classed('fade', false)
# 			d3.selectAll("bid_viz"+id).selectAll(`.ribbon-`).classed('highlight', false)
# 			for (var i = 0; i < matrix.length; i++) {
# 				d3.selectAll("bid_viz"+id).selectAll(`.ribbon-${d.index}-${i}`).classed('highlight', false)
# 				d3.selectAll("bid_viz"+id).selectAll(`.ribbon-${i}-${d.index}`).classed('highlight', false)
# 			}
#
# 			var numbers = new Set();
# 			var x = document.querySelectorAll(`[class^="ribbon-"]`)
# 			for (var i = 0; i < x.length; i++) {
# 				if (x[i].className.baseVal.indexOf(d.index.toString()) != -1) {
# 					numbers.add(x[i].className.baseVal.split(" ")[0].split("-")[1])
# 					numbers.add(x[i].clas

# %% [markdown]
# ### Save report to file

# %%
pfr = pandas_profiling.ProfileReport(df)
pfr.to_file("/tmp/example.html")
# Out:
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\pandas_profiling-1.4.1-py3.7.egg\pandas_profiling\describe.py:397: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-60ea8f3da20c> in <module>
#       1 pfr = pandas_profiling.ProfileReport(df)
# ----> 2 pfr.to_file("/tmp/example.html")
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\site-packages\pandas_profiling-1.4.1-py3.7.egg\pandas_profiling\__init__.py in to_file(self, outputfile)
#     152                 outputfile = 'profile_' + str(hash(self)) + ".html"
#     153             # TODO: should be done in the template
# --> 154             with codecs.open(outputfile, 'w+b', encoding='utf8') as self.file:
#     155                 self.file.write(templates.template('wrapper').render(content=self.html))
#     156
#
# c:\users\lucas\appdata\local\programs\python\python37\lib\codecs.py in open(filename, mode, encoding, errors, buffering)
#     902         # Force opening of the file in binary mode
#     903         mode = mode + 'b'
# --> 904     file = builtins.open(filename, mode, buffering)
#     905     if encoding is None:
#     906         return file
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/example.html'

# %% [markdown]
# #### Print existing ProfileReport object inline

# %%
pfr
